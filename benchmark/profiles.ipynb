# %%
import pandas as pd
data = pd.read_csv('./profile_tut_basic.csv', index_col=0)
data = data.T.apply(lambda x : x)
neworder = ['Final Typecheck', 'Includes Check', 'Length Check', 'Substitution Inlining' ]
data=data.reindex(columns=neworder)
data
# Out:
#                        Final Typecheck  Includes Check  Length Check  \
# Unoptimized                3546.012681     7749.181159    297.034420
# Substitution Inlining      2304.105656     4030.214454    299.507463
# Instance Cache             3526.619170     6364.732957    341.624808
# Length Cache               3540.979634     7802.247628      0.000000
# Optimized                  2421.909233     2820.031299      0.000000
#
#                        Substitution Inlining
# Unoptimized                         0.000000
# Substitution Inlining              40.722506
# Instance Cache                      0.000000
# Length Cache                        0.000000
# Optimized                          37.323944

# %%
plot = data.plot(kind='bar', stacked=True, rot=30)
fig = plot.get_figure()
fig.set_size_inches(12, 5)
fig.set_dpi(150)
plot.grid(axis='y', linewidth=0.2)
plot.set_xlabel("Applied Optimization")
plot.set_ylabel("Runtime [ms]")
# Out:
# Text(0, 0.5, 'Runtime [ms]')

# %%
import plotly.express as px
plt = px.bar(data, text_auto=True)

# %%
import pandas as pd
data = pd.read_csv('./cache.csv', index_col=0)
data = data.set_index('program')
data
# Out:
#                                  inst_hit  inst_miss  len_hit  len_miss
# program
# tut_basic_safe                        7.0        3.0      2.0       0.0
# tut_basic_unsafe                      7.0        3.0      2.0       0.0
# tut_tunnel_safe                      10.0        6.0      3.0       0.0
# tut_tunnel_unsafe                    10.0        6.0      3.0       0.0
# tut_load_balance_safe                10.0        5.0      3.0       0.0
# tut_load_balance_unsafe              10.0        5.0      3.0       0.0
# determined_forwarding_safe            0.0        2.0      0.0       0.0
# determined_forwarding_unsafe          0.0        1.0      0.0       0.0
# header_dependency_safe                0.0        0.0      2.0       0.0
# header_dependency_unsafe              0.0        0.0      2.0       0.0
# ipv4_opt_safe                         0.0        0.0      3.0       0.0
# ipv4_opt_unsafe                       0.0        0.0      3.0       0.0
# ...

# %%
plot = data.plot(kind='bar', stacked = False)
fig = plot.get_figure()
fig.set_size_inches(20, 10)
fig.set_dpi(150)
